# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import natsort
from PIL import Image
import os
from re import search
import shutil

from tqdm import tqdm
import cv2
import scipy as scipy

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Activation,Flatten,Conv2D,MaxPooling2D

# %%
model1=tf.keras.models.load_model(r"C:\Users\hch0a\OneDrive\Desktop\python\Apple\apple2.h5")

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 224, 224, 64)      1792
#
#  max_pooling2d_8 (MaxPoolin  (None, 112, 112, 64)      0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_9 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 64)        36928
#
#  max_pooling2d_10 (MaxPooli  (None, 28, 28, 64)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 4)                 100356
#
# ...
# Total params: 249860 (976.02 KB)
# Trainable params: 249860 (976.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
test_image=r"C:\Users\hch0a\Downloads\apple-scab-leaf-1.webp"
image_result=Image.open(test_image)

from tensorflow.keras.preprocessing import image


test_image=image.load_img(test_image,target_size=(224,224))
test_image=image.img_to_array(test_image)
test_image=test_image/255
test_image=np.expand_dims(test_image,axis=0)
result=model1.predict(test_image)
print(np.argmax(result))
Categories=['healthy','multipule_disease','rust','scab']
#Categories[np.argmax(result)]
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 1/1 [==============================] - 0s 51ms/step
# 3
